# %%
# %pip list
# Out:
# Package                               Version
# ------------------------------------- ---------
# aiohttp                               3.8.1
# aiosignal                             1.2.0
# ansiwrap                              0.8.4
# anyio                                 3.5.0
# appdirs                               1.4.4
# argon2-cffi                           21.3.0
# argon2-cffi-bindings                  21.2.0
# arrow                                 1.2.2
# asn1crypto                            1.5.1
# async-timeout                         4.0.2
# asynctest                             0.13.0
# attrs                                 21.4.0
# Babel                                 2.9.1
# backcall                              0.2.0
# backports.functools-lru-cache         1.6.4
# beatrix-jupyterlab                    3.1.7
# beautifulsoup4                        4.10.0
# binaryornot                           0.4.4
# black                                 22.1.0
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
import tensorflow as tf

# %%
pip install tensorflow

# %%
import tensorflow as tf

# %%
df = pd.read_csv("covid.csv")

# %%
df.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  24-02-20          5.0        5.0
# 1      AFG      Asia  Afghanistan  25-02-20          5.0        0.0
# 2      AFG      Asia  Afghanistan  26-02-20          5.0        0.0
# 3      AFG      Asia  Afghanistan  27-02-20          5.0        0.0
# 4      AFG      Asia  Afghanistan  28-02-20          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.671500e+04  2.668700e+04        26405.000000  2.504600e+04
# mean   1.948144e+06  8.001756e+03         7994.062776  3.668969e+04
# std    9.912608e+06  4.631324e+04        45856.963057  1.498411e+05
# min    1.000000e+00  0.000000e+00            0.000000  1.000000e+00
# 25%    1.992000e+03  0.000000e+00            7.857000  4.200000e+01
# 50%    2.447600e+04  6.900000e+01           98.714000  5.680000e+02
# 75%    2.649055e+05  9.130000e+02          993.143000  7.024500e+03
# max    1.423376e+08  1.102240e+06       884903.857000  1.411709e+06
#
#          new_deaths  new_deaths_smoothed  reproduction_rate  icu_patients  \
# count  25043.000000         24717.000000       19893.000000   4464.000000
# mean     106.046959           107.267364           0.988958    610.846774
# std      440.418462           434.182806           0.345703   1218.491422
# ...
